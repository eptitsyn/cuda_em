# %%
import scipy.stats as sts
import math
# %matplotlib inline

import os
import sys
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
np.random.seed(1234)

np.set_printoptions(formatter={'all':lambda x: '%.3f' % x})

# %%
df=pd.read_csv('2013-01-01_to_2015-12-31_1726454.csv', index_col=False)

# %%
a = ["FM-15"]

# %%
df = df[df["REPORT_TYPE"].isin(a)]

# %%
df = df[["DATE","HourlyDryBulbTemperature"]]

# %%
df = df.dropna()

# %%
df
# Out:
#                       DATE HourlyDryBulbTemperature
# 0      2013-01-01T00:53:00                       41
# 1      2013-01-01T01:53:00                       42
# 2      2013-01-01T02:53:00                       42
# 3      2013-01-01T03:53:00                       42
# 4      2013-01-01T04:53:00                       42
# 5      2013-01-01T05:53:00                       40
# 6      2013-01-01T06:53:00                       40
# 7      2013-01-01T07:53:00                       41
# 8      2013-01-01T08:53:00                       47
# 9      2013-01-01T09:51:00                       46
# 10     2013-01-01T09:53:00                       53
# 11     2013-01-01T10:53:00                       55
# 12     2013-01-01T11:53:00                       56
# 13     2013-01-01T12:53:00                       58
# 14     2013-01-01T13:53:00                       58
# 15     2013-01-01T14:53:00                       57
# 16     2013-01-01T15:53:00                       57
# ...

# %%
df[~df["REPORT_TYPE"].isin(a)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\dev\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'REPORT_TYPE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-247-1040cf107779> in <module>
# ----> 1 df[~df["REPORT_TYPE"].isin(a)]
#
# ...

# %%
df = df.reset_index(drop=True)

# %%
df[math.isnan(df.HourlyDryBulbTemperature)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-249-f034bd22f55a> in <module>
# ----> 1 df[math.isnan(df.HourlyDryBulbTemperature)]
#
# D:\dev\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#      91             return converter(self.iloc[0])
#      92         raise TypeError("cannot convert the series to "
# ---> 93                         "{0}".format(str(converter)))
#      94
#      95     wrapper.__name__ = "__{name}__".format(name=converter.__name__)
#
# TypeError: cannot convert the series to <class 'float'>

# %%
def strtoint(s):
    result = float(re.sub("[^0-9+.-]", "", str(s)))
    return result

# %%
import re
import math
data = np.array([])
prevopen = 0
tdata=0
for index,row in df.iterrows():
    print(f"{index} {row[1]}")
    tdata = strtoint(row[1])
    #print(f"{index} {tdata}")
    if index != 0:
        data =np.append(data, tdata-prevopen)
    prevopen = tdata
# Out:
# 0 41
# 1 42
# 2 42
# 3 42
# 4 42
# 5 40
# 6 40
# 7 41
# 8 47
# 9 46
# 10 53
# 11 55
# 12 56
# 13 58
# 14 58
# 15 57
# 16 57
# 17 54
# 18 53
# 19 52
# 20 49
# 21 44
# 22 43
# 23 41
# 24 38
# 25 38
# 26 37
# 27 37
# 28 34
# 29 34
# 30 35
# 31 37
# 32 37
# 33 48
# 34 57
# 35 59
# 36 61
# 37 62
# 38 60
# 39 59
# 40 57
# 41 54
# 42 52
# 43 47
# 44 45
# 45 42
# 46 42
# 47 41
# 48 39
# 49 37
# 50 38
# 51 37
# 52 36
# 53 36
# 54 34
# 55 34
# 56 37
# 57 49
# 58 58
# 59 62
# 60 64
# 61 64
# 62 65
# 63 65
# 64 63
# 65 57
# 66 51
# 67 48
# 68 45
# 69 45
# 70 40
# 71 40
# 72 39
# 73 39
# 74 37
# 75 35
# 76 37
# 77 35
# 78 34
# 79 33
# 80 37
# 81 49
# 82 59
# 83 61
# 84 61
# 85 63
# 86 64
# 87 64
# 88 62
# 89 57
# 90 52
# 91 46
# 92 45
# 93 44
# 94 42
# 95 40
# 96 41
# 97 38
# 98 38
# 99 36
# 100 38
# 101 36
# 102 36
# 103 37
# 104 38
# 105 50
# 106 57
# 107 58
# 108 59
# 109 59
# 110 58
# 111 58
# 112 56
# 113 53
# 114 52
# 115 48
# 116 49
# 117 49
# 118 50
# 119 50
# 120 49
# 121 49
# 122 49
# ...

# %%
len(data)
# Out:
# 26285

# %%
data
# Out:
# array([1.000, 0.000, 0.000, ..., -5.000, 2.000, -1.000])

# %%
np.savetxt("meteo_noaa_santabarbara_1726454.txt", data, fmt="%f")
