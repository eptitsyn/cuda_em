# %%
import scipy.stats as sts
import math
# %matplotlib inline

import os
import sys
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
plt.style.use('ggplot')
np.random.seed(1234)

np.set_printoptions(formatter={'all':lambda x: '%.3f' % x})

# %%
df=pd.read_csv('RI.IMOEX_180403_180502.csv ', sep=';')
df
# Out:
#        <TICKER>  <PER>    <DATE>  <TIME>   <OPEN>   <HIGH>    <LOW>  <CLOSE>  \
# 0      RI.IMOEX      1  20180403  100100  2259.18  2259.93  2257.18  2259.14
# 1      RI.IMOEX      1  20180403  100200  2259.54  2260.19  2259.05  2259.05
# 2      RI.IMOEX      1  20180403  100300  2259.38  2260.11  2259.06  2260.06
# 3      RI.IMOEX      1  20180403  100400  2259.92  2261.04  2259.78  2261.04
# 4      RI.IMOEX      1  20180403  100500  2261.23  2261.40  2259.16  2260.03
# 5      RI.IMOEX      1  20180403  100600  2260.08  2261.69  2259.32  2260.63
# 6      RI.IMOEX      1  20180403  100700  2260.47  2261.25  2260.01  2261.23
# 7      RI.IMOEX      1  20180403  100800  2261.25  2261.78  2261.25  2261.75
# 8      RI.IMOEX      1  20180403  100900  2261.81  2261.92  2260.94  2261.62
# 9      RI.IMOEX      1  20180403  101000  2261.58  2261.69  2260.67  2260.86
# 10     RI.IMOEX      1  20180403  101100  2260.97  2260.97  2258.79  2259.03
# ...

# %%
df = df.groupby('<DATE>').apply(lambda x: x.iloc[:-2] if len(x) > 1 else x).reset_index(drop=True)

# %%
df
# Out:
#       <TICKER>  <PER>    <DATE>  <TIME>   <OPEN>   <HIGH>    <LOW>  <CLOSE>  \
# 0     RI.IMOEX      5  20180323  100500  2272.32  2272.32  2259.78  2264.51
# 1     RI.IMOEX      5  20180323  101000  2264.09  2267.12  2262.95  2264.20
# 2     RI.IMOEX      5  20180323  101500  2264.42  2266.33  2263.37  2263.69
# 3     RI.IMOEX      5  20180323  102000  2263.66  2267.63  2263.42  2267.63
# 4     RI.IMOEX      5  20180323  102500  2267.69  2267.77  2264.97  2266.33
# 5     RI.IMOEX      5  20180323  103000  2266.34  2266.34  2263.35  2263.72
# 6     RI.IMOEX      5  20180323  103500  2263.56  2263.99  2260.38  2260.69
# 7     RI.IMOEX      5  20180323  104000  2260.63  2263.45  2260.40  2263.23
# 8     RI.IMOEX      5  20180323  104500  2263.22  2264.77  2263.01  2263.76
# 9     RI.IMOEX      5  20180323  105000  2263.87  2273.41  2263.87  2273.30
# 10    RI.IMOEX      5  20180323  105500  2273.33  2273.71  2270.96  2273.71
# ...

# %%
datas = []
prevopen = 0
for index, row in df.iterrows():
#for x in range(len(df)):    
    if prevopen != 0:
        datas = np.append(datas, row[4] - prevopen)
    prevopen = row[4]

# %%
len(datas)
# Out:
# 11439

# %%
with open('d://tmp//RI.IMOEX_180403_180502.txt', 'w') as f:
    for item in datas:
        f.write("%f\n" % item)
